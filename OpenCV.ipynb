# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\hp\anaconda3\lib\site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\hp\anaconda3\lib\site-packages (from opencv-python) (1.24.3)

# %%
import cv2

# %%
image = cv2.imread("Downloads/flowers.jpeg")

# %%
image.shape
# Out:
# (130, 114, 3)

# %%
image[0][0]
# Out:
# array([243, 243, 243], dtype=uint8)

# %%
cv2.imshow("image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

# %%
import cv2

# Load an image
image2 = cv2.imread("Downloads/flowers.jpeg", cv2.IMREAD_UNCHANGED)

# Check if the image is grayscale
if len(image.shape) == 2:
    print("The image is grayscale.")
elif len(image.shape) == 3:
    print("The image is a color image.")
else:
    print("The image has an unexpected number of channels.")
# Out:
# The image is a color image.

# %%
# Convert the color image to grayscale
grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Save the grayscale image
cv2.imwrite("grayscale_image.jpg", grayscale_image)

# Display the grayscale image (optional)
cv2.imshow("Grayscale Image", grayscale_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)

# %%
image_gray = cv2.cvtColor(grayscale_image, cv2.COLOR_BAYER_BG2GRAY)

# %%
plt.imshow(image_gray)

# %%
cv2.imshow('image', image_gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image.shape
# Out:
# (130, 114, 3)

# %%
image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# %%
cv2.imshow('image', image_hsv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
hue, sat, val = cv2.split(image_hsv)

# %%
add_val = -50

# %%
import numpy as np

# %%
#val

# %%
new_val = val.astype(np.int64) + add_val
new_val[new_val>255] = 255
new_val[new_val<0] = 0
new_val_uint8 = new_val.astype(np.uint8)

# %%
#new_val_uint8

# %%
image_new_hsv = cv2.merge([hue, sat, new_val_uint8])

# %%
image_new_bgr = cv2.cvtColor(image_new_hsv, cv2.COLOR_HSV2BGR)

# %%
cv2.imshow('image', image_new_bgr)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def change_bright_bgr(image, add_val):
    image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hue, sat, val = cv2.split(image_hsv)
    
    new_val = val.astype(np.int64) + add_val
    new_val[new_val>255] = 255
    new_val[new_val<0] = 0
    new_val_uint8 = new_val.astype(np.uint8)
    
    image_new_hsv = cv2.merge([hue, sat, new_val_uint8])
    image_new_bgr = cv2.cvtColor(image_new_hsv, cv2.COLOR_HSV2BGR)
    return image_new_bgr

# %%
cv2.imshow('image', change_bright_bgr(image, 1000))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image_grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('image', image_grey)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
sobel_x = cv2.Sobel(image_grey, ddepth=cv2.CV_64F, dx=1, dy=0)
sobel_y = cv2.Sobel(image_grey, ddepth=cv2.CV_64F, dx=0, dy=1)
sobel_xy = cv2.Sobel(image_grey, ddepth=cv2.CV_64F, dx=1, dy=1)

# %%
cv2.imshow('image', sobel_xy)
cv2.waitKey(0)
cv2.destroyAllWindows()
